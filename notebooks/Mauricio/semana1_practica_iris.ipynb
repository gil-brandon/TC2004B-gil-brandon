# %% [markdown]
# # Práctica Semana 1: Dataset Iris
#
# **Autor:** Gil Brandon Garcia Contreras
# **Fecha:** 9 de febrero de 2026
#
# ## Objetivo
#
# Practicar el uso de Jupyter Notebooks, pandas, y visualizaciones básicas usando el dataset Iris.
#
# Esta es una práctica de HERRAMIENTAS, no de análisis complejo.

# %%
# Imports básicos
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# Configuración
# %matplotlib inline
sns.set_style("whitegrid")

# %% [markdown]
# ## 1. Cargar Dataset

# %%
# Cargar Iris
iris = load_iris()

# Convertir a DataFrame
df = pd.DataFrame(
    data=iris.data,
    columns=iris.feature_names
)
df['species'] = iris.target
df['species_name'] = df['species'].map({
    0: 'setosa',
    1: 'versicolor',
    2: 'virginica'
})

# Ver primeras filas
df.head()

# %% [markdown]
# ## 2. Información Básica

# %%
print(f"Número de filas: {len(df)}")
print(f"Número de columnas: {df.shape[1]}")
print(f"\nColumnas: {list(df.columns)}")

# %%
# Información del DataFrame
df.info()

# %%
# Estadísticas descriptivas
df.describe()

# %% [markdown]
# ## 3. Visualizaciones Simples
#
# ### Histograma

# %%
plt.figure(figsize=(10, 5))
df['sepal length (cm)'].hist(bins=20, edgecolor='black')
plt.title('Distribución de Largo de Sépalo')
plt.xlabel('Largo (cm)')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
plt.figure(figsize=(8, 6))
for species in df['species_name'].unique():
    subset = df[df['species_name'] == species]
    plt.scatter(
        subset['sepal length (cm)'],
        subset['sepal width (cm)'],
        label=species,
        alpha=0.7
    )

plt.xlabel('Largo de Sépalo (cm)')
plt.ylabel('Ancho de Sépalo (cm)')
plt.title('Sépalos por Especie')
plt.legend()
plt.show()

# %% [markdown]
# ### Boxplot

# %%
plt.figure(figsize=(10, 6))
df.boxplot(column='petal length (cm)', by='species_name')
plt.suptitle('')  # Quitar título automático
plt.title('Largo de Pétalo por Especie')
plt.ylabel('Largo (cm)')
plt.show()

# %% [markdown]
# ## 4. Observaciones
#
# Tres cosas que noté en los datos:
#
# 1. Parece haber una relación entre el tamaña de los petalos y la especie
# 2. Parece que dentro de estas especies el mas chico puede ser de 4.4 y el mas grande llega a ser 7.9 un rango grande
# 3. La especie versicolor y virginica parecen colindar más que la setosa
#
# ## Conclusión
#
# Este notebook me permitió practicar:
# - Carga de datos
# - Uso de pandas
# - Creación de gráficas básicas
# - Documentación con Markdown
